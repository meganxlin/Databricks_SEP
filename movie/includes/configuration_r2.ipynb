# %%
username = 'meganxlin'

myPath = f"/dbfs/FileStore/tables/"

rawPath = myPath + "raw/"
rawData = [file.path for file in dbutils.fs.ls("dbfs:/FileStore/tables/")]
bronzePath = myPath + "bronze/"
silverPath = myPath + "silver/"
silverQuarantinePath = myPath + "silverQuarantine/"
goldPath = myPath + "gold/"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
